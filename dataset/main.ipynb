# %%
from deepface import DeepFace

df = DeepFace.find(img_path = "test.jpg", db_path = "./dbase")

print(df)
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: C:\Users\goglo\.deepface\weights\vgg_face_weights.h5
#   1%|▏         | 8.39M/580M [01:21<2:04:25, 76.6kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5e57e2ce2507> in <module>
#       1 from deepface import DeepFace
#       2
# ----> 3 df = DeepFace.find(img_path = "test.jpg", db_path = "./dbase")
#       4
#       5 print(df)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\deepface\DeepFace.py in find(img_path, db_path, model_name, distance_metric, model, enforce_detection, detector_backend, align, prog_bar, normalization)
#     506
#     507                         else: #model is not ensemble
# --> 508                                 model = build_model(model_name)
# ...
